# %%
import pandas as pd
import numpy as np

# %%
df_raw = pd.read_csv("/content/train_logs.csv")
df_raw.head()
# Out:
#          id  event_id  down_time  up_time  action_time       activity  \
# 0  001519c8         1       4526     4557         31.0  Nonproduction
# 1  001519c8         2       4558     4962        404.0  Nonproduction
# 2  001519c8         3     106571   106571          0.0  Nonproduction
# 3  001519c8         4     106686   106777         91.0          Input
# 4  001519c8         5     107196   107323        127.0          Input
#
#   down_event   up_event text_change  cursor_position  word_count
# 0  Leftclick  Leftclick    NoChange              0.0         0.0
# 1  Leftclick  Leftclick    NoChange              0.0         0.0
# 2      Shift      Shift    NoChange              0.0         0.0
# 3          q          q           q              1.0         1.0
# 4          q          q           q              2.0         1.0

# %% [markdown]
# **id** - The unique ID of the essay
#
# **event_id** - The index of the event, ordered chronologically
#
# **down_time** - The time of the down event in milliseconds
#
# **up_time** - The time of the up event in milliseconds
#
# **action_time** - The duration of the event (the difference between down_time and up_time)
#
# **activity** - The category of activity which the event belongs to
#
# - **Nonproduction** - The event does not alter the text in any way
#
# - **Input** - The event adds text to the essay
#
# - **Remove/Cut** - The event removes text from the essay
#
# - **Paste** - The event changes the text through a paste input
#
# - **Replace** - The event replaces a section of text with another string
#
# - **Move From [x1, y1] To [x2, y2]** - The event moves a section of text spanning character index x1, y1 to a new location x2, y2
#
# **down_event** - The name of the event when the key/mouse is pressed
#
# **up_event** - The name of the event when the key/mouse is released
#
# **text_change** - The text that changed as a result of the event (if any)
#
# **cursor_position** - The character index of the text cursor after the event
#
# **word_count** - The word count of the essay after the event

# %%
# Creating a new df based on the number of essays
# More features (columns) will be added to this df

df = pd.DataFrame({
    'id': df_raw["id"].unique()
})
df.head()
# Out:
#          id
# 0  001519c8
# 1  0022f953
# 2  0042269b
# 3  0059420b
# 4  0075873a

# %%
# Calculating the final word count for each essay
df_word = df_raw.groupby("id")['word_count'].max()
df = pd.merge(df, df_word, on="id", how="left")

# %%
# Turning milliseconds into minutes
df_raw['current_min'] = df_raw["down_time"]//60000

# %%
#Counting the number of events per essay
df_event = df_raw.groupby("id")['event_id'].count()

df = pd.merge(df, df_event, on="id", how="left")
df = df.rename(columns={"event_id": "event_count"})

# %%
# Calculating the time spend on writing the essay
df_time = df_raw.groupby("id")['current_min'].max()
df = pd.merge(df, df_time, on="id", how="left")
df = df.rename(columns={"current_min": "writing_time_min"})

# %%
# Calculating events per minute
df['events_per_min'] = df["event_count"] / df['writing_time_min']

# %%
# Calculating the number of TEXT changes made during the writing process
filter_text_change = df_raw["text_change"]!="NoChange"
df_filtered = df_raw[filter_text_change]
df_text_change = df_filtered.groupby("id")['text_change'].count()

df = pd.merge(df, df_text_change, on="id", how="left")

# %%
df = df.rename(columns={"text_change": "text_change_count"})

# %%
# Calculating text changes per minute
df['text_changes_per_min'] = df["text_change_count"] / df['writing_time_min']

# %%
# Calculating the number of sentences (based on the number of full stops)
sentence_filter = df_raw[(df_raw["text_change"].str.match('\.')) & (df_raw['activity'] != 'Remove/Cut')]
sentence_filter = df_raw[df_raw["up_event"] == '.']
df_sentence_count = sentence_filter.groupby("id")['text_change'].count()

df = pd.merge(df, df_sentence_count, on="id", how="left")

# %%
df = df.rename(columns={"text_change": "sentence_count"})

# %%
# Calculating total number of different activities
for activity in ['Input', 'Remove/Cut', 'Paste', 'Replace', 'Nonproduction']:
    df_activity_count = df_raw[df_raw['activity'] == activity].groupby("id")['activity'].count()
    column_name = f'{activity}_count'
    df_activity_count.name = column_name
    df = pd.merge(df, df_activity_count, on="id", how="left")
    df[column_name] = df[column_name].fillna(0)

# %%
# Pauses
df_raw['IKI'] = df_raw['down_time'] - df_raw.groupby('id')['up_time'].shift(1)
df_raw['IKI'] = df_raw['IKI'].fillna(0)
df_raw['IKI'] = df_raw['IKI'].clip(0)

PAUSE_THRESHOLD = 2000

# Total number of pauses (over 2000 ms) during writing process
pauses_count = df_raw[df_raw['IKI'] > PAUSE_THRESHOLD].groupby('id')['IKI'].count()
pauses_count.name = 'pauses_count'
df = pd.merge(df, pauses_count, on="id", how="left")

# %%
# Average duration of a pause
pauses_mean_duration = df_raw[df_raw['IKI'] > PAUSE_THRESHOLD].groupby('id')['IKI'].mean().round(0)
pauses_mean_duration.name = 'pause_mean_duration'
df = pd.merge(df, pauses_mean_duration, on="id", how="left")

# %%
# Calculating total time of pauses
pauses_time_sum = df_raw[df_raw['IKI'] > PAUSE_THRESHOLD].groupby('id')['IKI'].sum()
pauses_time_sum.name = 'pauses_time_sum'
df = pd.merge(df, pauses_time_sum, on="id", how="left")

# %%
# Calculating writing time in ms
writing_time_ms = df_raw.groupby('id')['up_time'].max()
writing_time_ms.name = 'writing_time_ms'
df = pd.merge(df, writing_time_ms, on="id", how="left")

# %%
# Average number of pauses per minute
df['pause_per_min'] = (df["pauses_count"] / df['writing_time_min']).round(2)

# Proportion of pauses during the writing process
df['pauses_share'] = (df["pauses_time_sum"] / df['writing_time_ms']).round(2)

# %%
df
# Out:
#           id  word_count  event_count  writing_time_min  events_per_min  \
# 0   001519c8       256.0         2557                30       85.233333
# 1   0022f953       323.0         2454                29       84.620690
# 2   0042269b       404.0         4136                29      142.620690
# 3   0059420b       206.0         1556                23       67.652174
# 4   0075873a       252.0         2531                27       93.740741
# 5   0081af50       275.0         2211                29       76.241379
# 6   0093f095       242.0         1765                29       60.862069
# 7   009e23ab       308.0         2353                29       81.137931
# 8   00e048f1       223.0         1585                29       54.655172
# 9   00e1f05a       739.0         7826                30      260.866667
# 10  00e713bd       574.0         4565                29      157.413793
# 11  00f0737e       252.0         2416                30       80.533333
# 12  00f8e84c       573.0         3721                29      128.310345
# 13  00fc9a6a       244.0         2701                26      103.884615
# 14  0144e4d5       234.0         2117                30       70.566667
# 15  014e7ae9       449.0         3919                30      130.633333
# 16  015aa732       421.0         3171                29      109.344828
# 17  0178a105       286.0         3446                29      118.827586
# 18  0182aa1c       406.0         3126                29      107.793103
# 19  0190ff4c       299.0         1922                27       71.185185
# 20  01963e20       414.0         5016                29      172.965517
# 21  019737b6       636.0         5526                29      190.551724
# 22  01992d32       410.0         2792                19      146.947368
#
#     text_change_count  text_changes_per_min  sentence_count  Input_count  \
# 0                2437             81.233333              21         2010
# 1                2200             75.862069              15         1938
# 2                3961            136.586207              21         3515
# 3                1457             63.347826              13         1304
# 4                2459             91.074074              23         1942
# 5                2135             73.620690              11         1794
# 6                1731             59.689655              15         1583
# 7                2198             75.793103              18         1975
# 8                1544             53.241379              23         1426
# 9                7598            253.266667              29         6145
# 10               4478            154.413793              18         3946
# 11               2018             67.266667              21         1780
# 12               3244            111.862069              25         3182
# 13               2565             98.653846              28         2029
# 14               1798             59.933333              37         1690
# 15               3829            127.633333              28         3289
# 16               3112            107.310345              23         2848
# 17               3326            114.689655              30         2444
# 18               3046            105.034483              19         2681
# 19               1876             69.481481              17         1758
# 20               4896            168.827586              31         3815
# 21               4515            155.689655              32         4095
# 22               2756            145.052632              23         2504
#
#     Remove/Cut_count  Paste_count  Replace_count  Nonproduction_count  \
# 0                417          0.0            7.0                  120
# 1                260          1.0            1.0                  254
# 2                439          0.0            7.0                  175
# 3                151          1.0            1.0                   99
# 4                517          0.0            0.0                   72
# 5                338          0.0            3.0                   76
# 6                148          0.0            0.0                   34
# 7                222          0.0            1.0                  155
# 8                118          0.0            0.0                   41
# 9               1446          0.0            7.0                  228
# 10               530          0.0            2.0                   87
# 11               237          0.0            1.0                  398
# 12                62          0.0            0.0                  477
# 13               534          2.0            0.0                  136
# 14               108          0.0            0.0                  319
# 15               529          1.0           10.0                   90
# 16               258          0.0            6.0                   59
# 17               878          1.0            3.0                  120
# 18               364          0.0            1.0                   80
# 19               118          0.0            0.0                   46
# 20              1075          0.0            6.0                  120
# 21               418          0.0            2.0                 1011
# 22               252          0.0            0.0                   35
#
#     pauses_count  pause_mean_duration  pauses_time_sum  writing_time_ms  \
# 0            124               9537.0        1182600.0          1801969
# 1             80              14678.0        1174268.0          1788969
# 2             77              14431.0        1111167.0          1771669
# 3             87               8828.0         768075.0          1404469
# 4             88              11880.0        1045463.0          1662472
# 5             49              23577.0        1155282.0          1778916
# 6             39              35156.0        1371097.0          1768197
# 7             56              20261.0        1134643.0          1799303
# 8             95              13017.0        1236616.0          1797498
# 9             88               5416.0         476630.0          1853697
# 10            72              12292.0         885054.0          1749111
# 11            57              16699.0         951816.0          1833804
# 12           126               5940.0         748472.0          1773964
# 13            99               9722.0         962463.0          1585825
# 14           127               6505.0         826154.0          1831176
# 15            99              11687.0        1157028.0          1833868
# 16            87              13325.0        1159288.0          1754540
# 17           132               6054.0         799152.0          1782121
# 18           108               8305.0         896992.0          1757984
# 19           110               8720.0         959224.0          1661246
# 20            61              15593.0         951172.0          1796902
# 21            50              20435.0        1021746.0          1793209
# 22            62               9265.0         574413.0          1173412
#
#     pause_per_min  pauses_share
# 0            4.13          0.66
# 1            2.76          0.66
# 2            2.66          0.63
# 3            3.78          0.55
# 4            3.26          0.63
# 5            1.69          0.65
# 6            1.34          0.78
# 7            1.93          0.63
# 8            3.28          0.69
# 9            2.93          0.26
# 10           2.48          0.51
# 11           1.90          0.52
# 12           4.34          0.42
# 13           3.81          0.61
# 14           4.23          0.45
# 15           3.30          0.63
# 16           3.00          0.66
# 17           4.55          0.45
# 18           3.72          0.51
# 19           4.07          0.58
# 20           2.10          0.53
# 21           1.72          0.57
# 22           3.26          0.49

# %%
# calcullating the start and end time of writing and most frequent activity
df_freq = df_raw.groupby("id").agg({
    'down_time': ['min', 'max'],
    'activity': lambda x: x.value_counts().index[0]
}).reset_index()

# %%
df_freq.columns = ['id', 'start_time', 'end_time', 'most_frequent_activity']

# %%
df_freq
# Out:
#           id  start_time  end_time most_frequent_activity
# 0   001519c8        4526   1801877                  Input
# 1   0022f953       30623   1788842                  Input
# 2   0042269b        4441   1771219                  Input
# 3   0059420b       41395   1404394                  Input
# 4   0075873a       78470   1662390                  Input
# 5   0081af50       42636   1778845                  Input
# 6   0093f095        6572   1768065                  Input
# 7   009e23ab      106549   1799221                  Input
# 8   00e048f1        5273   1797305                  Input
# 9   00e1f05a       10731   1853533                  Input
# 10  00e713bd         820   1749055                  Input
# 11  00f0737e       53017   1833682                  Input
# 12  00f8e84c        4663   1773898                  Input
# 13  00fc9a6a        3101   1585609                  Input
# 14  0144e4d5       83058   1830779                  Input
# 15  014e7ae9       18767   1833750                  Input
# 16  015aa732       14321   1754492                  Input
# 17  0178a105       28486   1782003                  Input
# 18  0182aa1c       31882   1757904                  Input
# 19  0190ff4c       40996   1661079                  Input
# 20  01963e20        1679   1796804                  Input
# 21  019737b6         921   1793063                  Input
# 22  01992d32       69136   1173331                  Input

# %%
df = pd.merge(df, df_freq, on="id", how='left')
df.head()
# Out:
#          id  word_count  event_count  writing_time_min  events_per_min  \
# 0  001519c8       256.0         2557                30       85.233333
# 1  0022f953       323.0         2454                29       84.620690
# 2  0042269b       404.0         4136                29      142.620690
# 3  0059420b       206.0         1556                23       67.652174
# 4  0075873a       252.0         2531                27       93.740741
#
#    text_change_count  text_changes_per_min  sentence_count  Input_count  \
# 0               2437             81.233333              21         2010
# 1               2200             75.862069              15         1938
# 2               3961            136.586207              21         3515
# 3               1457             63.347826              13         1304
# 4               2459             91.074074              23         1942
#
#    Remove/Cut_count  ...  Nonproduction_count  pauses_count  \
# 0               417  ...                  120           124
# 1               260  ...                  254            80
# 2               439  ...                  175            77
# 3               151  ...                   99            87
# 4               517  ...                   72            88
#
#    pause_mean_duration  pauses_time_sum  writing_time_ms  pause_per_min  \
# 0               9537.0        1182600.0          1801969           4.13
# 1              14678.0        1174268.0          1788969           2.76
# 2              14431.0        1111167.0          1771669           2.66
# 3               8828.0         768075.0          1404469           3.78
# 4              11880.0        1045463.0          1662472           3.26
#
#    pauses_share  start_time  end_time  most_frequent_activity
# 0          0.66        4526   1801877                   Input
# 1          0.66       30623   1788842                   Input
# 2          0.63        4441   1771219                   Input
# 3          0.55       41395   1404394                   Input
# 4          0.63       78470   1662390                   Input
#
# [5 rows x 22 columns]

# %%
# Calculating Average action time
df['total_writing_time'] = df['end_time'] - df['start_time']
df['Avg_time_between_events'] = df['total_writing_time'] / df['event_count']
df.head()
# Out:
#          id  word_count  event_count  writing_time_min  events_per_min  \
# 0  001519c8       256.0         2557                30       85.233333
# 1  0022f953       323.0         2454                29       84.620690
# 2  0042269b       404.0         4136                29      142.620690
# 3  0059420b       206.0         1556                23       67.652174
# 4  0075873a       252.0         2531                27       93.740741
#
#    text_change_count  text_changes_per_min  sentence_count  Input_count  \
# 0               2437             81.233333              21         2010
# 1               2200             75.862069              15         1938
# 2               3961            136.586207              21         3515
# 3               1457             63.347826              13         1304
# 4               2459             91.074074              23         1942
#
#    Remove/Cut_count  ...  pause_mean_duration  pauses_time_sum  \
# 0               417  ...               9537.0        1182600.0
# 1               260  ...              14678.0        1174268.0
# 2               439  ...              14431.0        1111167.0
# 3               151  ...               8828.0         768075.0
# 4               517  ...              11880.0        1045463.0
#
#    writing_time_ms  pause_per_min  pauses_share  start_time  end_time  \
# 0          1801969           4.13          0.66        4526   1801877
# 1          1788969           2.76          0.66       30623   1788842
# 2          1771669           2.66          0.63        4441   1771219
# 3          1404469           3.78          0.55       41395   1404394
# 4          1662472           3.26          0.63       78470   1662390
#
#    most_frequent_activity  total_writing_time  Avg_time_between_events
# 0                   Input             1797351               702.913962
# 1                   Input             1758219               716.470660
# 2                   Input             1766778               427.170696
# 3                   Input             1362999               875.963368
# 4                   Input             1583920               625.807981
#
# [5 rows x 24 columns]

# %%
# If overtime writing (if the writing time exceeded 30 minutes)
df['overtime_writing'] = df['writing_time_min'] > 30

# %%
# Average Action Time - average duration of the actions for each essay.
# Summing the durations of all actions in an essay and then dividing by the total number of actions.
# I leave values in the milliseconds due to it is very short in duration

total_action_time = df_raw.groupby('id')['action_time'].sum()
df = pd.merge(df, total_action_time, on='id', how='left')

df['average_action_time'] = df['action_time'] / df['event_count']
df = df.drop(columns=['action_time'])

# %%
# Total num of characters in the essay, including spaces etc:

# 'Input' and 'Paste' events, count each event as one character added
# "Remove/Cut" event as one character removed.
# I think the "Replace" action does not affect the total character count, as it's essentially a one-for-one substitution.

df_raw['chars_added'] = df_raw['activity'].apply(lambda x: 1 if x in ['Input', 'Paste'] else 0)
df_raw['chars_removed'] = df_raw['activity'].apply(lambda x: 1 if x == 'Remove/Cut' else 0)

total_chars_added = df_raw.groupby('id')['chars_added'].sum()
total_chars_removed = df_raw.groupby('id')['chars_removed'].sum()

df = pd.merge(df, total_chars_added, on='id', how='left')
df = pd.merge(df, total_chars_removed, on='id', how='left')

df['total_characters'] = df['chars_added'] - df['chars_removed']
df.drop(columns=['chars_added', 'chars_removed'], inplace=True)

# %%
# Average Characters per Minute - dividion of the total number of characters by the total writing time in minutes
# I left these values in float type, not rounded to the int, to keep the precision, but it can be converted to the int if needed
df['avg_characters_per_min'] = df['total_characters'] / df['writing_time_min']
df.head()
# Out:
#          id  word_count  event_count  writing_time_min  events_per_min  \
# 0  001519c8       256.0         2557                30       85.233333
# 1  0022f953       323.0         2454                29       84.620690
# 2  0042269b       404.0         4136                29      142.620690
# 3  0059420b       206.0         1556                23       67.652174
# 4  0075873a       252.0         2531                27       93.740741
#
#    text_change_count  text_changes_per_min  sentence_count  Input_count  \
# 0               2437             81.233333              21         2010
# 1               2200             75.862069              15         1938
# 2               3961            136.586207              21         3515
# 3               1457             63.347826              13         1304
# 4               2459             91.074074              23         1942
#
#    Remove/Cut_count  ...  pauses_share  start_time  end_time  \
# 0               417  ...          0.66        4526   1801877
# 1               260  ...          0.66       30623   1788842
# 2               439  ...          0.63        4441   1771219
# 3               151  ...          0.55       41395   1404394
# 4               517  ...          0.63       78470   1662390
#
#    most_frequent_activity  total_writing_time  Avg_time_between_events  \
# 0                   Input             1797351               702.913962
# 1                   Input             1758219               716.470660
# 2                   Input             1766778               427.170696
# 3                   Input             1362999               875.963368
# 4                   Input             1583920               625.807981
#
#    overtime_writing  average_action_time  total_characters  \
# 0             False           116.246774              1593
# 1             False           112.221271              1679
# 2             False           101.837766              3076
# 3             False           121.848329              1154
# 4             False           123.943896              1425
#
#    avg_characters_per_min
# 0               53.100000
# 1               57.896552
# 2              106.068966
# 3               50.173913
# 4               52.777778
#
# [5 rows x 28 columns]

# %% [markdown]
# # **Multicorrelation**

# %%
df_labels = pd.read_csv("/content/train_scores.csv")
df = pd.merge(df, df_labels, on='id', how='left')

# %%
df.head()
# Out:
#          id  word_count  event_count  writing_time_min  events_per_min  \
# 0  001519c8       256.0         2557                30       85.233333
# 1  0022f953       323.0         2454                29       84.620690
# 2  0042269b       404.0         4136                29      142.620690
# 3  0059420b       206.0         1556                23       67.652174
# 4  0075873a       252.0         2531                27       93.740741
#
#    text_change_count  text_changes_per_min  sentence_count  Input_count  \
# 0               2437             81.233333              21         2010
# 1               2200             75.862069              15         1938
# 2               3961            136.586207              21         3515
# 3               1457             63.347826              13         1304
# 4               2459             91.074074              23         1942
#
#    Remove/Cut_count  ...  start_time  end_time  most_frequent_activity  \
# 0               417  ...        4526   1801877                   Input
# 1               260  ...       30623   1788842                   Input
# 2               439  ...        4441   1771219                   Input
# 3               151  ...       41395   1404394                   Input
# 4               517  ...       78470   1662390                   Input
#
#    total_writing_time  Avg_time_between_events  overtime_writing  \
# 0             1797351               702.913962             False
# 1             1758219               716.470660             False
# 2             1766778               427.170696             False
# 3             1362999               875.963368             False
# 4             1583920               625.807981             False
#
#    average_action_time  total_characters  avg_characters_per_min  score
# 0           116.246774              1593               53.100000    3.5
# 1           112.221271              1679               57.896552    3.5
# 2           101.837766              3076              106.068966    6.0
# 3           121.848329              1154               50.173913    2.0
# 4           123.943896              1425               52.777778    4.0
#
# [5 rows x 29 columns]
# Warning: Total number of columns (29) exceeds max_columns (20) limiting to first (20) columns.

# %%
#Pearson correlation matrix

matrix = df.corr()
matrix
# Out:
# <ipython-input-36-db97ca63d318>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = df.corr()
#                          word_count  event_count  writing_time_min  \
# word_count                 1.000000     0.894081          0.164396
# event_count                0.894081     1.000000          0.264917
# writing_time_min           0.164396     0.264917          1.000000
# events_per_min             0.892945     0.974457          0.051664
# text_change_count          0.869069     0.990029          0.241574
# text_changes_per_min       0.862468     0.958161          0.022116
# sentence_count             0.317088     0.483413          0.192683
# Input_count                0.929413     0.987472          0.237625
# Remove/Cut_count           0.483971     0.793825          0.202819
# Paste_count               -0.256089    -0.135049         -0.207168
# Replace_count              0.371655     0.544695          0.376045
# Nonproduction_count        0.448250     0.383459          0.238038
# pauses_count              -0.088885    -0.072749          0.132610
# pause_mean_duration       -0.183476    -0.205628          0.180835
# pauses_time_sum           -0.444764    -0.453384          0.410005
# writing_time_ms            0.173800     0.282755          0.994979
# pause_per_min             -0.145919    -0.159609         -0.185285
# pauses_share              -0.561314    -0.605653          0.047853
# start_time                -0.399665    -0.427107         -0.281350
# end_time                   0.173900     0.282770          0.994983
# total_writing_time         0.236583     0.343631          0.983962
# Avg_time_between_events   -0.802892    -0.851215          0.014419
# overtime_writing                NaN          NaN               NaN
# average_action_time       -0.315138    -0.182103         -0.395341
# total_characters           0.974479     0.934385          0.220486
# avg_characters_per_min     0.950923     0.874521         -0.046724
# score                      0.503667     0.449735          0.151154
#
#                          events_per_min  text_change_count  \
# word_count                     0.892945           0.869069
# event_count                    0.974457           0.990029
# writing_time_min               0.051664           0.241574
# events_per_min                 1.000000           0.968602
# text_change_count              0.968602           1.000000
# text_changes_per_min           0.989302           0.972923
# sentence_count                 0.473635           0.444017
# Input_count                    0.968955           0.987038
# Remove/Cut_count               0.767404           0.837002
# Paste_count                   -0.115913          -0.125540
# Replace_count                  0.478421           0.584579
# Nonproduction_count            0.348147           0.249537
# pauses_count                  -0.113306          -0.058480
# pause_mean_duration           -0.243616          -0.225062
# pauses_time_sum               -0.553994          -0.455259
# writing_time_ms                0.070982           0.256671
# pause_per_min                 -0.133909          -0.138243
# pauses_share                  -0.632582          -0.595896
# start_time                    -0.371209          -0.427028
# end_time                       0.070994           0.256696
# total_writing_time             0.134936           0.319190
# Avg_time_between_events       -0.896668          -0.844570
# overtime_writing                    NaN                NaN
# average_action_time           -0.098438          -0.155621
# total_characters               0.921041           0.918250
# avg_characters_per_min         0.924618           0.863960
# score                          0.445174           0.491823
#
#                          text_changes_per_min  sentence_count  Input_count  \
# word_count                           0.862468        0.317088     0.929413
# event_count                          0.958161        0.483413     0.987472
# writing_time_min                     0.022116        0.192683     0.237625
# events_per_min                       0.989302        0.473635     0.968955
# text_change_count                    0.972923        0.444017     0.987038
# text_changes_per_min                 1.000000        0.431230     0.962751
# sentence_count                       0.431230        1.000000     0.423846
# Input_count                          0.962751        0.423846     1.000000
# Remove/Cut_count                     0.806517        0.421181     0.738345
# Paste_count                         -0.107226        0.077316    -0.186745
# Replace_count                        0.514918        0.217099     0.555533
# Nonproduction_count                  0.207788        0.411983     0.316914
# pauses_count                        -0.099412        0.361234    -0.074501
# pause_mean_duration                 -0.263138       -0.402452    -0.210914
# pauses_time_sum                     -0.555919       -0.351691    -0.447738
# writing_time_ms                      0.038562        0.212887     0.249751
# pause_per_min                       -0.111042        0.288955    -0.153531
# pauses_share                        -0.620475       -0.476449    -0.587845
# start_time                          -0.366214       -0.101822    -0.438259
# end_time                             0.038583        0.212675     0.249768
# total_writing_time                   0.103653        0.218003     0.314770
# Avg_time_between_events             -0.886391       -0.450397    -0.850079
# overtime_writing                          NaN             NaN          NaN
# average_action_time                 -0.068135       -0.048604    -0.223007
# total_characters                     0.899239        0.372065     0.969899
# avg_characters_per_min               0.910452        0.341990     0.920358
# score                                0.486107        0.126413     0.537189
#
#                          Remove/Cut_count  Paste_count  ...  pauses_share  \
# word_count                       0.483971    -0.256089  ...     -0.561314
# event_count                      0.793825    -0.135049  ...     -0.605653
# writing_time_min                 0.202819    -0.207168  ...      0.047853
# events_per_min                   0.767404    -0.115913  ...     -0.632582
# text_change_count                0.837002    -0.125540  ...     -0.595896
# text_changes_per_min             0.806517    -0.107226  ...     -0.620475
# sentence_count                   0.421181     0.077316  ...     -0.476449
# Input_count                      0.738345    -0.186745  ...     -0.587845
# Remove/Cut_count                 1.000000     0.107956  ...     -0.502886
# Paste_count                      0.107956     1.000000  ...      0.076094
# Replace_count                    0.555960    -0.003602  ...     -0.045663
# Nonproduction_count             -0.030475    -0.105182  ...     -0.256432
# pauses_count                     0.006713     0.249839  ...     -0.339452
# pause_mean_duration             -0.226553    -0.219881  ...      0.659159
# pauses_time_sum                 -0.390060    -0.022860  ...      0.928806
# writing_time_ms                  0.225277    -0.210706  ...      0.035222
# pause_per_min                   -0.058316     0.325976  ...     -0.351659
# pauses_share                    -0.502886     0.076094  ...      1.000000
# start_time                      -0.297945    -0.144183  ...     -0.058430
# end_time                         0.225323    -0.210752  ...      0.035248
# total_writing_time               0.266006    -0.170853  ...      0.043791
# Avg_time_between_events         -0.650569     0.010059  ...      0.565968
# overtime_writing                      NaN          NaN  ...           NaN
# average_action_time              0.104839     0.437146  ...      0.026236
# total_characters                 0.551892    -0.269400  ...     -0.545288
# avg_characters_per_min           0.493214    -0.255446  ...     -0.564551
# score                            0.233326    -0.209807  ...      0.072053
#
#                          start_time  end_time  total_writing_time  \
# word_count                -0.399665  0.173900            0.236583
# event_count               -0.427107  0.282770            0.343631
# writing_time_min          -0.281350  0.994983            0.983962
# events_per_min            -0.371209  0.070994            0.134936
# text_change_count         -0.427028  0.256696            0.319190
# text_changes_per_min      -0.366214  0.038583            0.103653
# sentence_count            -0.101822  0.212675            0.218003
# Input_count               -0.438259  0.249768            0.314770
# Remove/Cut_count          -0.297945  0.225323            0.266006
# Paste_count               -0.144183 -0.210752           -0.170853
# Replace_count             -0.399632  0.359542            0.410487
# Nonproduction_count       -0.136632  0.261612            0.270265
# pauses_count              -0.060669  0.102669            0.107364
# pause_mean_duration       -0.038102  0.194291            0.189035
# pauses_time_sum           -0.139267  0.400594            0.400947
# writing_time_ms           -0.256018  1.000000            0.983991
# pause_per_min              0.025327 -0.213285           -0.204473
# pauses_share              -0.058430  0.035248            0.043791
# start_time                 1.000000 -0.256038           -0.424196
# end_time                  -0.256038  1.000000            0.983995
# total_writing_time        -0.424196  0.983995            1.000000
# Avg_time_between_events    0.256675  0.013805           -0.034384
# overtime_writing                NaN       NaN                 NaN
# average_action_time        0.196781 -0.414957           -0.425005
# total_characters          -0.434465  0.227370            0.293089
# avg_characters_per_min    -0.350163 -0.038502            0.028480
# score                     -0.377740  0.144488            0.204988
#
#                          Avg_time_between_events  overtime_writing  \
# word_count                             -0.802892               NaN
# event_count                            -0.851215               NaN
# writing_time_min                        0.014419               NaN
# events_per_min                         -0.896668               NaN
# text_change_count                      -0.844570               NaN
# text_changes_per_min                   -0.886391               NaN
# sentence_count                         -0.450397               NaN
# Input_count                            -0.850079               NaN
# Remove/Cut_count                       -0.650569               NaN
# Paste_count                             0.010059               NaN
# Replace_count                          -0.479666               NaN
# Nonproduction_count                    -0.314074               NaN
# pauses_count                            0.020973               NaN
# pause_mean_duration                     0.319414               NaN
# pauses_time_sum                         0.517272               NaN
# writing_time_ms                         0.013853               NaN
# pause_per_min                           0.023389               NaN
# pauses_share                            0.565968               NaN
# start_time                              0.256675               NaN
# end_time                                0.013805               NaN
# total_writing_time                     -0.034384               NaN
# Avg_time_between_events                 1.000000               NaN
# overtime_writing                             NaN               NaN
# average_action_time                    -0.080827               NaN
# total_characters                       -0.816296               NaN
# avg_characters_per_min                 -0.844760               NaN
# score                                  -0.474184               NaN
#
#                          average_action_time  total_characters  \
# word_count                         -0.315138          0.974479
# event_count                        -0.182103          0.934385
# writing_time_min                   -0.395341          0.220486
# events_per_min                     -0.098438          0.921041
# text_change_count                  -0.155621          0.918250
# text_changes_per_min               -0.068135          0.899239
# sentence_count                     -0.048604          0.372065
# Input_count                        -0.223007          0.969899
# Remove/Cut_count                    0.104839          0.551892
# Paste_count                         0.437146         -0.269400
# Replace_count                       0.075032          0.486186
# Nonproduction_count                -0.231835          0.402920
# pauses_count                        0.063546         -0.094424
# pause_mean_duration                -0.132422         -0.179123
# pauses_time_sum                    -0.131426         -0.412830
# writing_time_ms                    -0.415015          0.227366
# pause_per_min                       0.191856         -0.168627
# pauses_share                        0.026236         -0.545288
# start_time                          0.196781         -0.434465
# end_time                           -0.414957          0.227370
# total_writing_time                 -0.425005          0.293089
# Avg_time_between_events            -0.080827         -0.816296
# overtime_writing                         NaN               NaN
# average_action_time                 1.000000         -0.313452
# total_characters                   -0.313452          1.000000
# avg_characters_per_min             -0.207416          0.959940
# score                              -0.110847          0.579969
#
#                          avg_characters_per_min     score
# word_count                             0.950923  0.503667
# event_count                            0.874521  0.449735
# writing_time_min                      -0.046724  0.151154
# events_per_min                         0.924618  0.445174
# text_change_count                      0.863960  0.491823
# text_changes_per_min                   0.910452  0.486107
# sentence_count                         0.341990  0.126413
# Input_count                            0.920358  0.537189
# Remove/Cut_count                       0.493214  0.233326
# Paste_count                           -0.255446 -0.209807
# Replace_count                          0.393363  0.456675
# Nonproduction_count                    0.347083 -0.132911
# pauses_count                          -0.143121 -0.047066
# pause_mean_duration                   -0.219027  0.027737
# pauses_time_sum                       -0.525307  0.122691
# writing_time_ms                       -0.038503  0.144560
# pause_per_min                         -0.134375 -0.102263
# pauses_share                          -0.564551  0.072053
# start_time                            -0.350163 -0.377740
# end_time                              -0.038502  0.144488
# total_writing_time                     0.028480  0.204988
# Avg_time_between_events               -0.844760 -0.474184
# overtime_writing                            NaN       NaN
# average_action_time                   -0.207416 -0.110847
# total_characters                       0.959940  0.579969
# avg_characters_per_min                 1.000000  0.562036
# score                                  0.562036  1.000000
#
# [27 rows x 27 columns]

# %% [markdown]
# Multicollinearity is indicated by the fact that the correlation between some pairs of features is stronger than their correlation with the dependent variable (score). For example the matrix shows the maximum
# correlation between the characteristics total_writing_time and writing_time_min (0.99) and it is greater than the correlation of either argument with the investigated characteristic, so we can draw the conclusion that these 2 characteristics are too strongly related to each other and in the same model both should not appear at the same time.
#
# To simplify the task we will choose a treshold of 0.9, considering that to be a very strong correlation.
#
# We will start with writing down pairs of features that are highly correlated.

# %% [markdown]
# #total_characters - word_count
#
# events_per_min - event_count
#
# text_change_count - event_count
#
# Input_count - event_count
#
# #end_time - writing_time_min
#
# #writing_time_ms - writing_time_min
#
# text_changes_per_min - events_per_min
#
# total_characters - text_change_count
#
# text_changes_per_min - text_change_count
#
# Input_count - text_change_count
#
# text_changes_per_min - Input_count
#
# text_changes_per_min - avg_characters_per_min
#
# #Input_count - word_count
#
# Input_count - total_characters
#
# #writing_time_ms - end_time
#
# #total_characters - avg_characters_per_min
#
# #pause_per_min - pause_count

# %%
import copy
df_model = copy.deepcopy(df)

# %%
#We will drop Input_count, writing_time_min, end_time, avg_characters_per_min, pause_per_min,
#events_per_min, total_characters,text_change_count.


#Drop one feature from the pair.

columns_to_drop = ['Input_count', 'writing_time_min', 'end_time', 'avg_characters_per_min',  'pause_per_min', 'events_per_min', 'total_characters', 'text_change_count']
df_model.drop(columns=columns_to_drop , inplace=True)
df_model.corr()
# Out:
# <ipython-input-38-4f8f1524c525>:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_model.corr()
#                          word_count  event_count  text_changes_per_min  \
# word_count                 1.000000     0.894081              0.862468
# event_count                0.894081     1.000000              0.958161
# text_changes_per_min       0.862468     0.958161              1.000000
# sentence_count             0.317088     0.483413              0.431230
# Remove/Cut_count           0.483971     0.793825              0.806517
# Paste_count               -0.256089    -0.135049             -0.107226
# Replace_count              0.371655     0.544695              0.514918
# Nonproduction_count        0.448250     0.383459              0.207788
# pauses_count              -0.088885    -0.072749             -0.099412
# pause_mean_duration       -0.183476    -0.205628             -0.263138
# pauses_time_sum           -0.444764    -0.453384             -0.555919
# writing_time_ms            0.173800     0.282755              0.038562
# pauses_share              -0.561314    -0.605653             -0.620475
# start_time                -0.399665    -0.427107             -0.366214
# total_writing_time         0.236583     0.343631              0.103653
# Avg_time_between_events   -0.802892    -0.851215             -0.886391
# overtime_writing                NaN          NaN                   NaN
# average_action_time       -0.315138    -0.182103             -0.068135
# score                      0.503667     0.449735              0.486107
#
#                          sentence_count  Remove/Cut_count  Paste_count  \
# word_count                     0.317088          0.483971    -0.256089
# event_count                    0.483413          0.793825    -0.135049
# text_changes_per_min           0.431230          0.806517    -0.107226
# sentence_count                 1.000000          0.421181     0.077316
# Remove/Cut_count               0.421181          1.000000     0.107956
# Paste_count                    0.077316          0.107956     1.000000
# Replace_count                  0.217099          0.555960    -0.003602
# Nonproduction_count            0.411983         -0.030475    -0.105182
# pauses_count                   0.361234          0.006713     0.249839
# pause_mean_duration           -0.402452         -0.226553    -0.219881
# pauses_time_sum               -0.351691         -0.390060    -0.022860
# writing_time_ms                0.212887          0.225277    -0.210706
# pauses_share                  -0.476449         -0.502886     0.076094
# start_time                    -0.101822         -0.297945    -0.144183
# total_writing_time             0.218003          0.266006    -0.170853
# Avg_time_between_events       -0.450397         -0.650569     0.010059
# overtime_writing                    NaN               NaN          NaN
# average_action_time           -0.048604          0.104839     0.437146
# score                          0.126413          0.233326    -0.209807
#
#                          Replace_count  Nonproduction_count  pauses_count  \
# word_count                    0.371655             0.448250     -0.088885
# event_count                   0.544695             0.383459     -0.072749
# text_changes_per_min          0.514918             0.207788     -0.099412
# sentence_count                0.217099             0.411983      0.361234
# Remove/Cut_count              0.555960            -0.030475      0.006713
# Paste_count                  -0.003602            -0.105182      0.249839
# Replace_count                 1.000000            -0.088043      0.054943
# Nonproduction_count          -0.088043             1.000000     -0.116491
# pauses_count                  0.054943            -0.116491      1.000000
# pause_mean_duration          -0.088719             0.062121     -0.800815
# pauses_time_sum               0.094317            -0.131502     -0.274899
# writing_time_ms               0.359542             0.261667      0.102774
# pauses_share                 -0.045663            -0.256432     -0.339452
# start_time                   -0.399632            -0.136632     -0.060669
# total_writing_time            0.410487             0.270265      0.107364
# Avg_time_between_events      -0.479666            -0.314074      0.020973
# overtime_writing                   NaN                  NaN           NaN
# average_action_time           0.075032            -0.231835      0.063546
# score                         0.456675            -0.132911     -0.047066
#
#                          pause_mean_duration  pauses_time_sum  \
# word_count                         -0.183476        -0.444764
# event_count                        -0.205628        -0.453384
# text_changes_per_min               -0.263138        -0.555919
# sentence_count                     -0.402452        -0.351691
# Remove/Cut_count                   -0.226553        -0.390060
# Paste_count                        -0.219881        -0.022860
# Replace_count                      -0.088719         0.094317
# Nonproduction_count                 0.062121        -0.131502
# pauses_count                       -0.800815        -0.274899
# pause_mean_duration                 1.000000         0.676482
# pauses_time_sum                     0.676482         1.000000
# writing_time_ms                     0.194204         0.400566
# pauses_share                        0.659159         0.928806
# start_time                         -0.038102        -0.139267
# total_writing_time                  0.189035         0.400947
# Avg_time_between_events             0.319414         0.517272
# overtime_writing                         NaN              NaN
# average_action_time                -0.132422        -0.131426
# score                               0.027737         0.122691
#
#                          writing_time_ms  pauses_share  start_time  \
# word_count                      0.173800     -0.561314   -0.399665
# event_count                     0.282755     -0.605653   -0.427107
# text_changes_per_min            0.038562     -0.620475   -0.366214
# sentence_count                  0.212887     -0.476449   -0.101822
# Remove/Cut_count                0.225277     -0.502886   -0.297945
# Paste_count                    -0.210706      0.076094   -0.144183
# Replace_count                   0.359542     -0.045663   -0.399632
# Nonproduction_count             0.261667     -0.256432   -0.136632
# pauses_count                    0.102774     -0.339452   -0.060669
# pause_mean_duration             0.194204      0.659159   -0.038102
# pauses_time_sum                 0.400566      0.928806   -0.139267
# writing_time_ms                 1.000000      0.035222   -0.256018
# pauses_share                    0.035222      1.000000   -0.058430
# start_time                     -0.256018     -0.058430    1.000000
# total_writing_time              0.983991      0.043791   -0.424196
# Avg_time_between_events         0.013853      0.565968    0.256675
# overtime_writing                     NaN           NaN         NaN
# average_action_time            -0.415015      0.026236    0.196781
# score                           0.144560      0.072053   -0.377740
#
#                          total_writing_time  Avg_time_between_events  \
# word_count                         0.236583                -0.802892
# event_count                        0.343631                -0.851215
# text_changes_per_min               0.103653                -0.886391
# sentence_count                     0.218003                -0.450397
# Remove/Cut_count                   0.266006                -0.650569
# Paste_count                       -0.170853                 0.010059
# Replace_count                      0.410487                -0.479666
# Nonproduction_count                0.270265                -0.314074
# pauses_count                       0.107364                 0.020973
# pause_mean_duration                0.189035                 0.319414
# pauses_time_sum                    0.400947                 0.517272
# writing_time_ms                    0.983991                 0.013853
# pauses_share                       0.043791                 0.565968
# start_time                        -0.424196                 0.256675
# total_writing_time                 1.000000                -0.034384
# Avg_time_between_events           -0.034384                 1.000000
# overtime_writing                        NaN                      NaN
# average_action_time               -0.425005                -0.080827
# score                              0.204988                -0.474184
#
#                          overtime_writing  average_action_time     score
# word_count                            NaN            -0.315138  0.503667
# event_count                           NaN            -0.182103  0.449735
# text_changes_per_min                  NaN            -0.068135  0.486107
# sentence_count                        NaN            -0.048604  0.126413
# Remove/Cut_count                      NaN             0.104839  0.233326
# Paste_count                           NaN             0.437146 -0.209807
# Replace_count                         NaN             0.075032  0.456675
# Nonproduction_count                   NaN            -0.231835 -0.132911
# pauses_count                          NaN             0.063546 -0.047066
# pause_mean_duration                   NaN            -0.132422  0.027737
# pauses_time_sum                       NaN            -0.131426  0.122691
# writing_time_ms                       NaN            -0.415015  0.144560
# pauses_share                          NaN             0.026236  0.072053
# start_time                            NaN             0.196781 -0.377740
# total_writing_time                    NaN            -0.425005  0.204988
# Avg_time_between_events               NaN            -0.080827 -0.474184
# overtime_writing                      NaN                  NaN       NaN
# average_action_time                   NaN             1.000000 -0.110847
# score                                 NaN            -0.110847  1.000000

# %%
df_model.head()
# Out:
#          id  word_count  event_count  text_changes_per_min  sentence_count  \
# 0  001519c8       256.0         2557             81.233333              21
# 1  0022f953       323.0         2454             75.862069              15
# 2  0042269b       404.0         4136            136.586207              21
# 3  0059420b       206.0         1556             63.347826              13
# 4  0075873a       252.0         2531             91.074074              23
#
#    Remove/Cut_count  Paste_count  Replace_count  Nonproduction_count  \
# 0               417          0.0            7.0                  120
# 1               260          1.0            1.0                  254
# 2               439          0.0            7.0                  175
# 3               151          1.0            1.0                   99
# 4               517          0.0            0.0                   72
#
#    pauses_count  ...  pauses_time_sum  writing_time_ms  pauses_share  \
# 0           124  ...        1182600.0          1801969          0.66
# 1            80  ...        1174268.0          1788969          0.66
# 2            77  ...        1111167.0          1771669          0.63
# 3            87  ...         768075.0          1404469          0.55
# 4            88  ...        1045463.0          1662472          0.63
#
#    start_time  most_frequent_activity total_writing_time  \
# 0        4526                   Input            1797351
# 1       30623                   Input            1758219
# 2        4441                   Input            1766778
# 3       41395                   Input            1362999
# 4       78470                   Input            1583920
#
#    Avg_time_between_events  overtime_writing  average_action_time  score
# 0               702.913962             False           116.246774    3.5
# 1               716.470660             False           112.221271    3.5
# 2               427.170696             False           101.837766    6.0
# 3               875.963368             False           121.848329    2.0
# 4               625.807981             False           123.943896    4.0
#
# [5 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
X = df_model.drop(['id', 'most_frequent_activity'], axis=1)
X = X.fillna(0)

#X_test = X[X['is_test'] == True].drop(['is_test'], axis=1)
#X = X[X['is_test'] == False].drop(['is_test'], axis=1)

X_train, X_val, y_train, y_val = train_test_split(X, df_labels['score'], random_state=0, test_size=0.20, stratify = df_labels['score'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-00d8c9b9dac6> in <cell line: 8>()
#       6 #X = X[X['is_test'] == False].drop(['is_test'], axis=1)
#       7
# ----> 8 X_train, X_val, y_train, y_val = train_test_split(X, df_labels['score'], random_state=0, test_size=0.20, stratify = df_labels['score'])
#       9
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2557         raise ValueError("At least one array required as input")
#    2558
# -> 2559     arrays = indexable(*arrays)
#    2560
#    2561     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [23, 2471]

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, mean_squared_error

random_state = np.random.seed(0) # random seed for consistency

RFR = RandomForestRegressor(max_depth=2, random_state=random_state)

RFR.fit(X_train, y_train)

predictions_RFR = RFR.predict(X_val.to_numpy())

rmse_RFR = mean_squared_error(y_val, predictions_RFR, squared = False)
print(rmse_RFR)

# %%
import statsmodels.api as sm

# Define independent variables (predictors)
X = df[['word_count', 'total_writing_time']]

# Define dependent variable
y = df['score']

# Add a constant term to the independent variables matrix (for intercept)
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Print the regression results
print(model.summary())

# %%
#Aleksandra
# Activity column group by activities
# Pauses (total number, per minute, average)

#Yaroslava:
# Number of characters (total in the essay, avg per minute)
# Overtime (yes or no?)
# Average action time

#Ehab
# Most frequent activity
# Average time between events

#Anastastija
# Move From explore futher..
# Number of sentences based on the number of full stops/excl. marks

# %% [markdown]
# # Train labels (essay grades)

# %%
df_labels = pd.read_csv("../data/train_scores.csv")
df_labels.head()

# %%
import matplotlib.pyplot as plt

plt.hist(df_labels['score'], bins = 12)
plt.show()

# %%
df_labels.groupby('score')['id'].count().plot.bar(width =0.8)
